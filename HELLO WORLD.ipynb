# %%
# Hello World program
message = "Hello, World!"
print(message)
name = "Google Colab"
print("Welcome to", name)
for i in range(3):
    print("Hello World", i + 1)
print("Program finished")
# Out:
# Hello, World!
# Welcome to Google Colab
# Hello World 1
# Hello World 2
# Hello World 3
# Program finished
